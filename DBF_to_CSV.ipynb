# %%
import os
import pandas as pd
from simpledbf import Dbf5

# %%
import os
import pandas as pd
from simpledbf import Dbf5

for file in os.listdir('dbf'):
    if file.endswith(".dbf"):
        dbf = Dbf5('dbf/' + file, codec='ISO-8859-1')
        print(dbf)
        dbf.to_csv("csv/" + os.path.splitext(file)[0] + ".csv")
        
lista = []
for file_csv in os.listdir('csv'):
    #print(file_csv)
    #chunks = pd.DataFrame(chunks)
    chunks = pd.read_csv("csv/" + file_csv ,encoding= 'ISO-8859-1')
    chunks_lista = chunks
    lista.append(chunks_lista)
    df2 = pd.concat(lista)
df2.to_csv("csv_concat/" + os.path.splitext(file)[0] + ".csv",index=False)
# Out:
# ...
# c:\users\yuan\miniconda3\envs\jupyter_conda_python_3.8\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (64) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
chunks = pd.read_csv("csv_concat/wwwwwwwwwwwwwwwwwww.csv" ,encoding= 'ISO-8859-1')
chunks
# Out:
#         TP_NOT ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  ID_MUNICIP  \
# 0            2      Z209  2010-01-11   201002    2010         35      355410
# 1            2      Z209  2010-01-07   201001    2010         35      355410
# 2            2      Z209  2010-01-26   201004    2010         35      355410
# 3            2      Z209  2010-01-15   201002    2010         35      350450
# 4            2      Z209  2010-01-13   201002    2010         23      230440
# ...        ...       ...         ...      ...     ...        ...         ...
# 104644       2      Z209  2010-12-20   201051    2010         35      355030
# 104645       2      Z209  2010-12-02   201048    2010         35      355070
# 104646       2      Z209  2010-12-31   201052    2010         35      355030
# 104647       2      Z209  2010-12-08   201049    2010         41      410830
# 104648       2      Z209  2010-12-04   201048    2010         41      410830
#
# ...

# %%
for file in os.listdir('dbf'):
    if file.endswith(".dbf"):
        dbf = Dbf5('dbf/' + file, codec='ISO-8859-1')
        print(dbf)
        dbf.to_csv("csv/" + os.path.splitext(file)[0] + ".csv")
        
frames = [ pd.read_csv("csv/" + file_csv ,encoding= 'ISO-8859-1') for file_csv in os.listdir('csv') ]
result = pd.concat(frames)
display(result)

# %%
frames = [ pd.read_csv("csv/" + file_csv ,encoding= 'ISO-8859-1') for file_csv in os.listdir('csv') ]
result = pd.concat(frames)
display(result)
# Out:
# C:\Users\Yuan\AppData\Local\Temp/ipykernel_3780/2700768182.py:1: DtypeWarning: Columns (64) have mixed types.Specify dtype option on import or set low_memory=False.
#   frames = [ pd.read_csv("csv/" + file_csv ,encoding= 'ISO-8859-1') for file_csv in os.listdir('csv') ]
#        TP_NOT ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  ID_MUNICIP  \
# 0           2      Z209  2010-01-11   201002    2010         35      355410
# 1           2      Z209  2010-01-07   201001    2010         35      355410
# 2           2      Z209  2010-01-26   201004    2010         35      355410
# 3           2      Z209  2010-01-15   201002    2010         35      350450
# 4           2      Z209  2010-01-13   201002    2010         23      230440
# ...       ...       ...         ...      ...     ...        ...         ...
# 34878       2      Z209  2010-12-20   201051    2010         35      355030
# 34879       2      Z209  2010-12-02   201048    2010         35      355070
# ...

# %%
lista = []
for file_csv in os.listdir('csv'):
    #print(file_csv)
    #chunks = pd.DataFrame(chunks)
    chunks = pd.read_csv("csv/" + file_csv ,encoding= 'ISO-8859-1')
    chunks_lista = chunks
    lista.append(chunks_lista)
    df2 = pd.concat(lista)
display(df2)
# Out:
# c:\users\yuan\miniconda3\envs\jupyter_conda_python_3.8\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (64) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        TP_NOT ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  ID_MUNICIP  \
# 0           2      Z209  2010-01-11   201002    2010         35      355410
# 1           2      Z209  2010-01-07   201001    2010         35      355410
# 2           2      Z209  2010-01-26   201004    2010         35      355410
# 3           2      Z209  2010-01-15   201002    2010         35      350450
# 4           2      Z209  2010-01-13   201002    2010         23      230440
# ...       ...       ...         ...      ...     ...        ...         ...
# 34878       2      Z209  2010-12-20   201051    2010         35      355030
# 34879       2      Z209  2010-12-02   201048    2010         35      355070
# ...

# %%
import os
from simpledbf import Dbf5

for file in os.listdir('C:/Users/Yuan/Desktop/DBF/files_me'):
        if file.endswith(".dbf"):
                dbf = Dbf5('C:/Users/Yuan/Desktop/DBF/files_me/' + file, codec='ISO-8859-1')
                dbf.to_csv("C:/Users/Yuan/Desktop/DBF/files_me/csv/" + os.path.splitext(file)[0] + ".csv")
                print("C:/Users/Yuan/Desktop/DBF/files_me/" + file + " converted to csv")
# codec='utf-8' --> 'ISO-8859-1'

#dbf = Dbf5("ACBIBR10.dbf", codec='ISO-8859-1')
#dbf.to_csv("qweqwe.csv")
#print("data/" + file + " converted to csv")
